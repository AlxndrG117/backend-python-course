# %%
import requests

print("Lista de Reproducción\n")

# Referencia: https://www.deezer.com/en/channels/explore

print("Ingresa la palabra que te gustaría") 
print("Ejemplo: 'rock', y obtendrás un playlist de canciones o artistas que incluyan la palabra rock")

word_to_search = input()

url = "https://deezerdevs-deezer.p.rapidapi.com/search" 
querystring = {"q":word_to_search} 
headers = {    
    "X-RapidAPI-Key": "3ed98f551fmshe4e6260228c4eadp13db17jsn8c893e1194da",    
    "X-RapidAPI-Host": "deezerdevs-deezer.p.rapidapi.com"
} 
response = requests.request("GET", url, headers=headers, params=querystring).json()

my_list = []

for element in response['data']:
    my_dict = {"Artista": element['artist']['name'],
            "Canción": element['title']}
    my_list.append(my_dict) 
    
print(my_list)
print("Comprehension: ")

for element in my_list:
    print(element)

# elements = [element for element in my_list] Según el módulo, este es el verdadero list comprehension, pero al imprimirlo, sale exactamente igual al código original.
# print(elements)
# Out:
# Lista de Reproducción
#
# Ingresa la palabra que te gustaría
# Ejemplo: 'rock', y obtendrás un playlist de canciones o artistas que incluyan la palabra rock
# rock
# [{'Artista': 'Post Malone', 'Canción': 'rockstar'}, {'Artista': 'LISA', 'Canción': 'Rockstar'}, {'Artista': 'Elton John', 'Canción': "Rocket Man (I Think It's Going To Be A Long, Long Time)"}, {'Artista': 'Junior H', 'Canción': 'ROCKSTAR'}, {'Artista': 'Justin Timberlake', 'Canción': 'Rock Your Body'}, {'Artista': 'DaBaby', 'Canción': 'ROCKSTAR'}, {'Artista': 'Nickelback', 'Canción': 'Rockstar'}, {'Artista': 'The Clash', 'Canción': 'Rock the Casbah (Remastered)'}, {'Artista': 'Clean Bandit', 'Canción': 'Rockabye (feat. Sean Paul & Anne-Marie)'}, {'Artista': 'Kiss', 'Canción': 'Rock And Roll All Nite'}, {'Artista': 'R3HAB', 'Canción': 'Rock My Body'}, {'Artista': 'Bob Sinclar', 'Canción': 'Rock This Party (Everybody Dance Now)'}, {'Artista': 'Scorpions', 'Canción': 'Rock You Like a Hurricane (2015 - Remaster)'}, {'Artista': 'Rockwell', 'Canción': "Somebody's Watching Me"}, {'Artista': 'AC/DC', 'Canción': 'Rock N Roll Train'}, {'Artista': 'Led Zeppelin', 'Canción': 'Rock and Roll (Remaster)'}, {'Artista': 'Michael Jackson', 'Canción': 'Rock with You (Single Version)'}, {'Artista': 'LISA', 'Canción': 'Rockstar (Extended)'}, {'Artista': 'Scorpions', 'Canción': 'Rock You Like a Hurricane (2011)'}, {'Artista': 'Aaliyah', 'Canción': 'Rock The Boat'}, {'Artista': 'Bailey Zimmerman', 'Canción': 'Rock and A Hard Place'}, {'Artista': 'blink-182', 'Canción': 'The Rock Show'}, {'Artista': 'Neil Young', 'Canción': "Rockin' in the Free World"}, {'Artista': 'Los Master Plus', 'Canción': 'Rockstar'}, {'Artista': 'Gary Glitter', 'Canción': "Rock 'n' Roll (Part 2)"}]
# Comprehension:
# {'Artista': 'Post Malone', 'Canción': 'rockstar'}
# {'Artista': 'LISA', 'Canción': 'Rockstar'}
# {'Artista': 'Elton John', 'Canción': "Rocket Man (I Think It's Going To Be A Long, Long Time)"}
# {'Artista': 'Junior H', 'Canción': 'ROCKSTAR'}
# {'Artista': 'Justin Timberlake', 'Canción': 'Rock Your Body'}
# {'Artista': 'DaBaby', 'Canción': 'ROCKSTAR'}
# {'Artista': 'Nickelback', 'Canción': 'Rockstar'}
# {'Artista': 'The Clash', 'Canción': 'Rock the Casbah (Remastered)'}
# {'Artista': 'Clean Bandit', 'Canción': 'Rockabye (feat. Sean Paul & Anne-Marie)'}
# {'Artista': 'Kiss', 'Canción': 'Rock And Roll All Nite'}
# {'Artista': 'R3HAB', 'Canción': 'Rock My Body'}
# {'Artista': 'Bob Sinclar', 'Canción': 'Rock This Party (Everybody Dance Now)'}
# {'Artista': 'Scorpions', 'Canción': 'Rock You Like a Hurricane (2015 - Remaster)'}
# {'Artista': 'Rockwell', 'Canción': "Somebody's Watching Me"}
# {'Artista': 'AC/DC', 'Canción': 'Rock N Roll Train'}
# {'Artista': 'Led Zeppelin', 'Canción': 'Rock and Roll (Remaster)'}
# {'Artista': 'Michael Jackson', 'Canción': 'Rock with You (Single Version)'}
# {'Artista': 'LISA', 'Canción': 'Rockstar (Extended)'}
# {'Artista': 'Scorpions', 'Canción': 'Rock You Like a Hurricane (2011)'}
# {'Artista': 'Aaliyah', 'Canción': 'Rock The Boat'}
# {'Artista': 'Bailey Zimmerman', 'Canción': 'Rock and A Hard Place'}
# {'Artista': 'blink-182', 'Canción': 'The Rock Show'}
# {'Artista': 'Neil Young', 'Canción': "Rockin' in the Free World"}
# {'Artista': 'Los Master Plus', 'Canción': 'Rockstar'}
# {'Artista': 'Gary Glitter', 'Canción': "Rock 'n' Roll (Part 2)"}
