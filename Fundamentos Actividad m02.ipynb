# %%
my_input = eval(input("Ingresa un número: "))
print(my_input)
print(type(my_input))
# Out:
# Ingresa un número: 117
# 117
# <class 'int'>

# %%
my_float= eval(input("Ingresa una calificación: "))
print(my_float)
print(type(my_float))
# Out:
# Ingresa una calificación: 9.3
# 9.3
# <class 'float'>

# %%
my_string = input ("Ingresa una cantidad: ")
print(my_string)
print(type(my_string))
# Out:
# Ingresa una cantidad: 117
# 117
# <class 'str'>
