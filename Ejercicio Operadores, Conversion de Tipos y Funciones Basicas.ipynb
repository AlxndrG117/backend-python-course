# %%
operacion = input("selecione operacion: 1=suma, 2=resta, 3=multiplicacion, 4=division, 5=potencia")
dict_usr_txt = {
    "1":'suma',
    "2":'resta',
    "3":'multiplicacion',
    "4":'division',
    "5":'potencia'
    
}
print("operacion selecionada: ", dict_usr_txt[operacion])
num1 = (input("ingrese su num 1"))
num2 = (input("ingrese su num 2"))
num3 = (input("ingrese su num 3"))
num4 = (input("ingrese su num 4"))
num5 = (input("ingrese su num 5"))
list_usr = [num1,num2,num3,num4,num5]
print("numeros seleccioandos: ", list_usr)
print(type(list_usr))
dict_usr_opc = {
    "1":'+',
    "2":'-',
    "3":'*',
    "4":'/',
    "5":'**'
# Out:
# selecione operacion: 1=suma, 2=resta, 3=multiplicacion, 4=division, 5=potencia1
# operacion selecionada:  suma
# ingrese su num 11
# ingrese su num 21
# ingrese su num 31
# ingrese su num 41
# ingrese su num 51
# numeros seleccioandos:  ['1', '1', '1', '1', '1']
# <class 'list'>
# El resultado de su suma es:  5
