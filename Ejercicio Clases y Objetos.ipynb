# %%
class Producto:
    def _init_(self, nombre, precio, descripcion):
        self.nombre = nombre
        self.precio = precio
        self.descripcion = descripcion
        
    def print_attributes(self):
        print("Nombre: ", self.nombre)
        print("Precio: ", self.precio)
        print("Descripción: ", self.descripcion)

    def aplicar_descuento(self, descuento):
        self.precio *= (1 - descuento/100)

class categoria(Producto):
    def _init_(self, nombre, precio, descripcion, tax):
        #Inicializar
        Producto._init_(self, nombre, precio, descripcion)
        self.tax = 10
    def disponible(self):
        return True
