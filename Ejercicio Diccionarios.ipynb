# %%
# !pip install pokebase
# Out:
# Collecting pokebase
#   Obtaining dependency information for pokebase from https://files.pythonhosted.org/packages/77/6f/c96b0855965a1d151fc930168ed2e78f7c414872531899036f0b4b5093d4/pokebase-1.4.1-py3-none-any.whl.metadata
#   Downloading pokebase-1.4.1-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: requests in /Users/alexanderg117/anaconda3/lib/python3.11/site-packages (from pokebase) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/alexanderg117/anaconda3/lib/python3.11/site-packages (from requests->pokebase) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/alexanderg117/anaconda3/lib/python3.11/site-packages (from requests->pokebase) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/alexanderg117/anaconda3/lib/python3.11/site-packages (from requests->pokebase) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/alexanderg117/anaconda3/lib/python3.11/site-packages (from requests->pokebase) (2023.7.22)
# Downloading pokebase-1.4.1-py3-none-any.whl (11 kB)
# Installing collected packages: pokebase
# Successfully installed pokebase-1.4.1

# %%
import pokebase as pb
import requests

pokemon_to_search = input("Ingresa el nombre de un pokemon\n\n")
data = pb.pokemon(pokemon_to_search).__dict__
id_ = data.get('id_')
name = data.get('name')
height = data.get('height')
weight = data.get('weight')

print("ID: ", id_) 
print("Nombre: ", name) 
print("Altura: ", height) 
print("Peso: ", weight)

url = "https://pokeapi.co/api/v2/characteristic/{id}/".format(id=id_) 
response = requests.get(url)
for description_dict in response.json().get("descriptions"):
    if description_dict.get("language", {}).get("name") == "es":
        description = description_dict.get("description")
        print("Descripción: ",description)
# Out:
# Ingresa el nombre de un pokemon
#
# pikachu
# ID:  25
# Nombre:  pikachu
# Altura:  4
# Peso:  60
# Descripción:  Le gusta relajarse
